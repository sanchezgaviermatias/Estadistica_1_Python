# %% [markdown]
# # Aplicación Titanic
# ---

# %%
import pandas as pd

titanic = pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ## Análisis NaN
# ---

# %%
titanic.isna().sum().sort_values(ascending=False)
# Out:
# Cabin          327
# Age             86
# Fare             1
# Embarked         0
# Ticket           0
# Parch            0
# SibSp            0
# Sex              0
# Name             0
# Pclass           0
# PassengerId      0
# dtype: int64

# %%
#Elimino Cabina 
titanic.drop("Cabin", inplace=True, axis=1)

# %%
#Calculo la media
media = titanic.Age.mean(skipna=True)
print(media)
media2 =titanic.Fare.mean(skipna=True)

# Reemplazo NaN con la Media
titanic["Age"].fillna(media, inplace=True)
titanic["Fare"].fillna(media2, inplace=True)
# Out:
# 30.272590361445783

# %%
titanic.isna().sum().sort_values(ascending=False)
# Out:
# Embarked       0
# Fare           0
# Ticket         0
# Parch          0
# SibSp          0
# Age            0
# Sex            0
# Name           0
# Pclass         0
# PassengerId    0
# dtype: int64

# %% [markdown]
# ##  Manejo de texto
# ---
# Utilizamos **.str** para acceder a los métodos asociados a strings!

# %%
titanic["Name"].str.lower()
# Out:
# 0                                  kelly, mr. james
# 1                  wilkes, mrs. james (ellen needs)
# 2                         myles, mr. thomas francis
# 3                                  wirz, mr. albert
# 4      hirvonen, mrs. alexander (helga e lindqvist)
#                            ...
# 413                              spector, mr. woolf
# 414                    oliva y ocana, dona. fermina
# 415                    saether, mr. simon sivertsen
# 416                             ware, mr. frederick
# 417                        peter, master. michael j
# Name: Name, Length: 418, dtype: object

# %%
mask = titanic["Name"].str.contains("Albert")
titanic[mask]
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 3            895       3                         Wirz, Mr. Albert    male
# 7            899       2             Caldwell, Mr. Albert Francis    male
# 55           947       3                     Rice, Master. Albert    male
# 210         1102       3              Andersen, Mr. Albert Karvin    male
# 259         1151       3                 Midtsjo, Mr. Karl Albert    male
# 361         1253       2  Mallet, Mrs. Albert (Antoinette Magnin)  female
#
#       Age  SibSp  Parch           Ticket     Fare Embarked
# 3    27.0      0      0           315154   8.6625        S
# 7    26.0      1      1           248738  29.0000        S
# 55   10.0      4      1           382652  29.1250        Q
# 210  32.0      0      0           C 4001  22.5250        S
# 259  21.0      0      0           345501   7.7750        S
# 361  24.0      1      1  S.C./PARIS 2079  37.0042        C

# %%
titanic["Name"] = titanic["Name"].str.split(",").str.get(0)
titanic.head()
# Out:
#    PassengerId  Pclass      Name     Sex   Age  SibSp  Parch   Ticket  \
# 0          892       3     Kelly    male  34.5      0      0   330911
# 1          893       3    Wilkes  female  47.0      1      0   363272
# 2          894       2     Myles    male  62.0      0      0   240276
# 3          895       3      Wirz    male  27.0      0      0   315154
# 4          896       3  Hirvonen  female  22.0      1      1  3101298
#
#       Fare Cabin Embarked
# 0   7.8292   NaN        Q
# 1   7.0000   NaN        S
# 2   9.6875   NaN        Q
# 3   8.6625   NaN        S
# 4  12.2875   NaN        S

# %% [markdown]
# ### Variables Dummies
# ---

# %%
titanic["Sex_short"] = titanic["Sex"].replace({"male": 0, "female": 1})
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Sex_short
# 0  34.5      0      0   330911   7.8292   NaN        Q          0
# 1  47.0      1      0   363272   7.0000   NaN        S          1
# 2  62.0      0      0   240276   9.6875   NaN        Q          0
# 3  27.0      0      0   315154   8.6625   NaN        S          0
# 4  22.0      1      1  3101298  12.2875   NaN        S          1

# %%
pd.get_dummies(data = titanic, columns=["embarked"])
# Out:
#      passengerid  pclass                                          name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         sex       age  sibsp  parch              ticket      fare  embarked_C  \
# 0      male  34.50000      0      0              330911    7.8292           0
# 1    female  47.00000      1      0              363272    7.0000           0
# 2      male  62.00000      0      0              240276    9.6875           0
# 3      male  27.00000      0      0              315154    8.6625           0
# 4    female  22.00000      1      1             3101298   12.2875           0
# ..      ...       ...    ...    ...                 ...       ...         ...
# 413    male  30.27259      0      0           A.5. 3236    8.0500           0
# 414  female  39.00000      0      0            PC 17758  108.9000           1
# 415    male  38.50000      0      0  SOTON/O.Q. 3101262    7.2500           0
# 416    male  30.27259      0      0              359309    8.0500           0
# 417    male  30.27259      1      1                2668   22.3583           1
#
#      embarked_Q  embarked_S
# 0             1           0
# 1             0           1
# 2             1           0
# 3             0           1
# 4             0           1
# ..          ...         ...
# 413           0           1
# 414           0           0
# 415           0           1
# 416           0           1
# 417           0           0
#
# [418 rows x 12 columns]

# %% [markdown]
# ### Cambio de los Títulos
# ---

# %%
titanic.columns
# Out:
# Index(['passengerid', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'embarked', 'valor Z edad'],
#       dtype='object')

# %%
titanic.rename(columns = {'pclass':'clase'})
# Out:
#      passengerid  clase                                          name     sex  \
# 0            892      3                              Kelly, Mr. James    male
# 1            893      3              Wilkes, Mrs. James (Ellen Needs)  female
# 2            894      2                     Myles, Mr. Thomas Francis    male
# 3            895      3                              Wirz, Mr. Albert    male
# 4            896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..           ...    ...                                           ...     ...
# 413         1305      3                            Spector, Mr. Woolf    male
# 414         1306      1                  Oliva y Ocana, Dona. Fermina  female
# 415         1307      3                  Saether, Mr. Simon Sivertsen    male
# 416         1308      3                           Ware, Mr. Frederick    male
# 417         1309      3                      Peter, Master. Michael J    male
#
#           age  sibsp  parch              ticket      fare embarked  \
# 0    34.50000      0      0              330911    7.8292        Q
# 1    47.00000      1      0              363272    7.0000        S
# 2    62.00000      0      0              240276    9.6875        Q
# 3    27.00000      0      0              315154    8.6625        S
# 4    22.00000      1      1             3101298   12.2875        S
# ..        ...    ...    ...                 ...       ...      ...
# 413  30.27259      0      0           A.5. 3236    8.0500        S
# 414  39.00000      0      0            PC 17758  108.9000        C
# 415  38.50000      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416  30.27259      0      0              359309    8.0500        S
# 417  30.27259      1      1                2668   22.3583        C
#
#      valor Z edad
# 0    3.345917e-01
# 1    1.323944e+00
# 2    2.511166e+00
# 3   -2.590195e-01
# 4   -6.547602e-01
# ..            ...
# 413 -2.530716e-15
# 414  6.907583e-01
# 415  6.511842e-01
# 416 -2.530716e-15
# 417 -2.530716e-15
#
# [418 rows x 11 columns]

# %%
titanic.columns = [x.lower() for x in titanic.columns]
titanic.head()
# Out:
#    passengerid  pclass                                          name     sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     age  sibsp  parch   ticket     fare embarked
# 0  34.5      0      0   330911   7.8292        Q
# 1  47.0      1      0   363272   7.0000        S
# 2  62.0      0      0   240276   9.6875        Q
# 3  27.0      0      0   315154   8.6625        S
# 4  22.0      1      1  3101298  12.2875        S

# %% [markdown]
# ### Columnas en Función de otras Columnas
# ---

# %%
titanic["valor Z edad"] = ( titanic["age"] -  titanic["age"].mean() )/ titanic["age"].std()
titanic.head()
# Out:
#    passengerid  pclass                                          name     sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     age  sibsp  parch   ticket     fare embarked  valor Z edad
# 0  34.5      0      0   330911   7.8292        Q      0.334592
# 1  47.0      1      0   363272   7.0000        S      1.323944
# 2  62.0      0      0   240276   9.6875        Q      2.511166
# 3  27.0      0      0   315154   8.6625        S     -0.259019
# 4  22.0      1      1  3101298  12.2875        S     -0.654760

# %% [markdown]
# ### Funciones de Summary
# ---

# %% [markdown]
# **idxmin()** y **idxmax()** devuelven el índice del mínimo y el máximo

# %%
id_mas_joven = titanic["age"].idxmin() 
id_mas_viejo = titanic["age"].idxmax()

# %%
titanic.iloc[[id_mas_joven, id_mas_viejo]]
# Out:
#      passengerid  pclass                                               name  \
# 354         1246       3            Dean, Miss. Elizabeth Gladys Millvina""
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
#
#         sex    age  sibsp  parch     ticket    fare cabin embarked  sex_short  \
# 354  female   0.17      1      2  C.A. 2315  20.575   NaN        S          1
# 96   female  76.00      1      0      19877  78.850   C46        S          1
#
#      valor Z edad
# 354     -2.122710
# 96       3.224507

# %%
titanic["sex"].value_counts()
# Out:
# male      266
# female    152
# Name: sex, dtype: int64

# %% [markdown]
# ### Discretizando Variables Continuas
#
# ---

# %%
titanic["edad_discreta"] = pd.qcut(titanic["age"], [0, .25, .5, .75, 1])
titanic.sort_values(by="age")
# Out:
#      passengerid  pclass                                               name  \
# 354         1246       3            Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093       3            Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173       3                     Peacock, Master. Alfred Edward
# 307         1199       3                          Aks, Master. Philip Frank
# 250         1142       2                              West, Miss. Barbara J
# ..           ...     ...                                                ...
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 236         1128       1                           Warren, Mr. Frank Manley
# 81           973       1                                 Straus, Mr. Isidor
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
#
#         sex    age  sibsp  parch              ticket      fare embarked  \
# 354  female   0.17      1      2           C.A. 2315   20.5750        S
# 201    male   0.33      0      2              347080   14.4000        S
# 281    male   0.75      1      1  SOTON/O.Q. 3101315   13.7750        S
# 307    male   0.83      0      1              392091    9.3500        S
# 250  female   0.92      1      2          C.A. 34651   27.7500        S
# ..      ...    ...    ...    ...                 ...       ...      ...
# 305  female  64.00      1      1              112901   26.5500        S
# 179  female  64.00      0      2            PC 17756   83.1583        C
# 236    male  64.00      1      0              110813   75.2500        C
# 81     male  67.00      1      0            PC 17483  221.7792        S
# 96   female  76.00      1      0               19877   78.8500        S
#
#      valor Z edad  edad_discreta
# 354     -2.382564  (0.169, 23.0]
# 201     -2.369901  (0.169, 23.0]
# 281     -2.336658  (0.169, 23.0]
# 307     -2.330327  (0.169, 23.0]
# 250     -2.323203  (0.169, 23.0]
# ..            ...            ...
# 305      2.669462  (35.75, 76.0]
# 179      2.669462  (35.75, 76.0]
# 236      2.669462  (35.75, 76.0]
# 81       2.906907  (35.75, 76.0]
# 96       3.619240  (35.75, 76.0]
#
# [418 rows x 12 columns]
