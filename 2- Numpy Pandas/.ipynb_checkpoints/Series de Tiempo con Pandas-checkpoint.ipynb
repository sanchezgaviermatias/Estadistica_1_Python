# %% [markdown]
# # Series de Tiempo con Pandas
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ypf = pd.read_csv("YPF.csv", skiprows=2, sep=";")
ypf.head()
# Out:
#   Fecha Cotización  Apertura  Máximo  Mínimo  Cierre  Cierre ajustado  \
# 0       06/26/2020    619.00  622.95  600.00  608.85           608.85
# 1       06/25/2020    605.05  625.00  600.15  618.45           618.45
# 2       06/24/2020    608.95  611.00  591.00  597.90           597.90
# 3       06/23/2020    613.05  624.90  608.65  611.10           611.10
# 4       06/22/2020    618.00  618.00  588.00  608.65           608.65
#
#     Volumen Monto Volumen Nominal
# 0   64,246,839.75      104,830.00
# 1   62,791,109.15      102,732.00
# 2   66,405,588.45      110,467.00
# 3  125,013,430.75      202,079.00
# 4  207,277,304.60      343,731.00

# %%
ypf["Fecha Cotización"]
# Out:
# 0       06/26/2020
# 1       06/25/2020
# 2       06/24/2020
# 3       06/23/2020
# 4       06/22/2020
#            ...
# 4592     12/7/2001
# 4593     12/6/2001
# 4594     12/5/2001
# 4595     12/4/2001
# 4596     12/3/2001
# Name: Fecha Cotización, Length: 4597, dtype: object

# %% [markdown]
# Es importante usar el tipo de objeto **DatTime**.
#
# Para esto  usamos la funcion **.to_datetime()**

# %%
pd.to_datetime(ypf["Fecha Cotización"])
# Out:
# 0      2020-06-26
# 1      2020-06-25
# 2      2020-06-24
# 3      2020-06-23
# 4      2020-06-22
#           ...
# 4592   2001-12-07
# 4593   2001-12-06
# 4594   2001-12-05
# 4595   2001-12-04
# 4596   2001-12-03
# Name: Fecha Cotización, Length: 4597, dtype: datetime64[ns]

# %% [markdown]
# Pandas trata de inferir el formato de la Serie, pero puede fallar. Se puede entonces espceificar manualmente con el parámetro **format=**
#
# - [info sobre códgio de strings](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior)

# %%
ypf["Fecha Cotización"]
# Out:
# 0       06/26/2020
# 1       06/25/2020
# 2       06/24/2020
# 3       06/23/2020
# 4       06/22/2020
#            ...
# 4592     12/7/2001
# 4593     12/6/2001
# 4594     12/5/2001
# 4595     12/4/2001
# 4596     12/3/2001
# Name: Fecha Cotización, Length: 4597, dtype: object

# %% [markdown]
# ### Reoredenando en base al ínidice

# %%
ypf = ypf.sort_index()

# %%
r = pd.to_datetime(ypf["Fecha Cotización"], format='%m/%d/%Y')
ypf["Fecha Cotización"] = r

ypf["Fecha Cotización"]
# Out:
# 0      2020-06-26
# 1      2020-06-25
# 2      2020-06-24
# 3      2020-06-23
# 4      2020-06-22
#           ...
# 4592   2001-12-07
# 4593   2001-12-06
# 4594   2001-12-05
# 4595   2001-12-04
# 4596   2001-12-03
# Name: Fecha Cotización, Length: 4597, dtype: datetime64[ns]

# %% [markdown]
# ###  Otro método para transfromar a Serie de Tiempo
# ---

# %%
ypf = pd.read_csv("YPF.csv", skiprows=2, sep=";", index_col="Fecha Cotización", parse_dates=True)

# %%
ypf.index
# Out:
# DatetimeIndex(['2020-06-26', '2020-06-25', '2020-06-24', '2020-06-23',
#                '2020-06-22', '2020-06-19', '2020-06-18', '2020-06-17',
#                '2020-06-16', '2020-06-12',
#                ...
#                '2001-12-14', '2001-12-13', '2001-12-12', '2001-12-11',
#                '2001-12-10', '2001-12-07', '2001-12-06', '2001-12-05',
#                '2001-12-04', '2001-12-03'],
#               dtype='datetime64[ns]', name='Fecha Cotización', length=4597, freq=None)

# %% [markdown]
# ### El group by de Series de Tiempo
#
# Rule parámetro [Offsets signficado](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases)

# %%
media_anual =ypf.resample(rule='A').mean() #anual

media_anual.head()
# Out:
#                     Apertura      Máximo      Mínimo      Cierre  \
# Fecha Cotización
# 2001-12-31         20.466667   21.319048   20.333333   21.266667
# 2002-12-31         43.049617   43.903448   42.732950   43.736782
# 2003-12-31         71.129310   71.835632   70.729502   71.505556
# 2004-12-31        117.298473  118.081107  116.618702  117.400382
# 2005-12-31        164.499231  165.890385  162.999038  164.457115
#
#                   Cierre ajustado
# Fecha Cotización
# 2001-12-31                    0.0
# 2002-12-31                    0.0
# 2003-12-31                    0.0
# 2004-12-31                    0.0
# 2005-12-31                    0.0

# %%
plt.figure(figsize=(15,8))
media_anual["Cierre"].plot(kind="bar")

# %%
ypf.resample(rule='M').sum() #mensual
# Out:
#                   Apertura    Máximo    Mínimo    Cierre  Cierre ajustado
# Fecha Cotización
# 2001-12-31          429.80    447.70    427.00    446.60             0.00
# 2002-01-31          761.55    784.10    760.95    783.70             0.00
# 2002-02-28          860.75    868.55    857.70    866.10             0.00
# 2002-03-31          975.60    996.20    971.85    996.15             0.00
# 2002-04-30         1226.50   1258.00   1217.25   1258.00             0.00
# ...                    ...       ...       ...       ...              ...
# 2020-02-29        14063.30  14264.85  13761.85  13976.15         13976.15
# 2020-03-31         8686.95   8993.90   8121.70   8451.30          8451.30
# 2020-04-30         7959.95   8276.45   7680.05   8030.45          8030.45
# 2020-05-31         9690.70  10003.60   9418.75   9733.70          9733.70
# 2020-06-30        12301.10  12675.25  11894.00  12309.50         12309.50
#
# [223 rows x 5 columns]

# %%
ypf.head()
# Out:
#                   Apertura  Máximo  Mínimo  Cierre  Cierre ajustado  \
# Fecha Cotización
# 2020-06-26          619.00  622.95  600.00  608.85           608.85
# 2020-06-25          605.05  625.00  600.15  618.45           618.45
# 2020-06-24          608.95  611.00  591.00  597.90           597.90
# 2020-06-23          613.05  624.90  608.65  611.10           611.10
# 2020-06-22          618.00  618.00  588.00  608.65           608.65
#
#                    Volumen Monto Volumen Nominal
# Fecha Cotización
# 2020-06-26         64,246,839.75      104,830.00
# 2020-06-25         62,791,109.15      102,732.00
# 2020-06-24         66,405,588.45      110,467.00
# 2020-06-23        125,013,430.75      202,079.00
# 2020-06-22        207,277,304.60      343,731.00

# %%
ypf.shift(1)
# Out:
#                   Apertura  Máximo  Mínimo  Cierre  Cierre ajustado  \
# Fecha Cotización
# 2020-06-26             NaN     NaN     NaN     NaN              NaN
# 2020-06-25          619.00  622.95  600.00  608.85           608.85
# 2020-06-24          605.05  625.00  600.15  618.45           618.45
# 2020-06-23          608.95  611.00  591.00  597.90           597.90
# 2020-06-22          613.05  624.90  608.65  611.10           611.10
# ...                    ...     ...     ...     ...              ...
# 2001-12-07           20.50   20.50   20.00   20.50             0.00
# 2001-12-06           19.50   20.90   19.50   20.90             0.00
# 2001-12-05           18.00   19.00   17.00   19.00             0.00
# 2001-12-04           17.00   18.00   17.00   18.00             0.00
# 2001-12-03           16.00   16.50   16.00   16.50             0.00
#
#                    Volumen Monto Volumen Nominal
# Fecha Cotización
# 2020-06-26                   NaN             NaN
# 2020-06-25         64,246,839.75      104,830.00
# 2020-06-24         62,791,109.15      102,732.00
# 2020-06-23         66,405,588.45      110,467.00
# 2020-06-22        125,013,430.75      202,079.00
# ...                          ...             ...
# 2001-12-07             49,067.00        2,420.00
# 2001-12-06            249,645.00       12,131.00
# 2001-12-05            491,641.00       28,568.00
# 2001-12-04              6,073.00          349.00
# 2001-12-03              9,567.00          585.00
#
# [4597 rows x 7 columns]

# %% [markdown]
# ### Media Movíl

# %%
plt.figure(figsize=(13,9))
ypf["Cierre"].plot(kind="line")
plt.title("Valor de Cierre - YPF", pad=10, fontdict={'fontsize':20});

# %%
media_movil = ypf.rolling(window=7).mean()
media_movil.head(8)
# Out:
#                     Apertura      Máximo      Mínimo      Cierre  \
# Fecha Cotización
# 2020-06-26               NaN         NaN         NaN         NaN
# 2020-06-25               NaN         NaN         NaN         NaN
# 2020-06-24               NaN         NaN         NaN         NaN
# 2020-06-23               NaN         NaN         NaN         NaN
# 2020-06-22               NaN         NaN         NaN         NaN
# 2020-06-19               NaN         NaN         NaN         NaN
# 2020-06-18        609.871429  621.264286  594.121429  607.071429
# 2020-06-17        615.014286  627.557143  596.264286  609.107143
#
#                   Cierre ajustado
# Fecha Cotización
# 2020-06-26                    NaN
# 2020-06-25                    NaN
# 2020-06-24                    NaN
# 2020-06-23                    NaN
# 2020-06-22                    NaN
# 2020-06-19                    NaN
# 2020-06-18             607.071429
# 2020-06-17             609.107143

# %%
plt.figure(figsize=(13,9))
ypf["Cierre"].plot(kind="line")
media_movil["Cierre"].plot(kind="line")
plt.title("Valor de Cierre - YPF", pad=10, fontdict={'fontsize':20});

# %%
media_movil = ypf.rolling(window=30).mean()
media_movil.head(35)
# Out:
#                     Apertura      Máximo      Mínimo      Cierre  \
# Fecha Cotización
# 2020-06-26               NaN         NaN         NaN         NaN
# 2020-06-25               NaN         NaN         NaN         NaN
# 2020-06-24               NaN         NaN         NaN         NaN
# 2020-06-23               NaN         NaN         NaN         NaN
# 2020-06-22               NaN         NaN         NaN         NaN
# 2020-06-19               NaN         NaN         NaN         NaN
# 2020-06-18               NaN         NaN         NaN         NaN
# 2020-06-17               NaN         NaN         NaN         NaN
# 2020-06-16               NaN         NaN         NaN         NaN
# 2020-06-12               NaN         NaN         NaN         NaN
# 2020-06-11               NaN         NaN         NaN         NaN
# 2020-06-10               NaN         NaN         NaN         NaN
# 2020-06-09               NaN         NaN         NaN         NaN
# 2020-06-08               NaN         NaN         NaN         NaN
# 2020-06-05               NaN         NaN         NaN         NaN
# 2020-06-04               NaN         NaN         NaN         NaN
# 2020-06-03               NaN         NaN         NaN         NaN
# 2020-06-02               NaN         NaN         NaN         NaN
# 2020-06-01               NaN         NaN         NaN         NaN
# 2020-05-29               NaN         NaN         NaN         NaN
# 2020-05-28               NaN         NaN         NaN         NaN
# 2020-05-27               NaN         NaN         NaN         NaN
# 2020-05-26               NaN         NaN         NaN         NaN
# 2020-05-22               NaN         NaN         NaN         NaN
# 2020-05-21               NaN         NaN         NaN         NaN
# 2020-05-20               NaN         NaN         NaN         NaN
# 2020-05-19               NaN         NaN         NaN         NaN
# 2020-05-18               NaN         NaN         NaN         NaN
# 2020-05-15               NaN         NaN         NaN         NaN
# 2020-05-14        608.686667  627.368333  589.628333  610.138333
# 2020-05-13        605.553333  624.305000  585.596667  606.071667
# 2020-05-12        602.551667  621.638333  582.758333  602.778333
# 2020-05-11        597.953333  617.771667  578.325000  599.205000
# 2020-05-08        593.188333  613.275000  573.706667  594.761667
# 2020-05-07        587.756667  608.201667  569.193333  589.950000
#
#                   Cierre ajustado
# Fecha Cotización
# 2020-06-26                    NaN
# 2020-06-25                    NaN
# 2020-06-24                    NaN
# 2020-06-23                    NaN
# 2020-06-22                    NaN
# 2020-06-19                    NaN
# 2020-06-18                    NaN
# 2020-06-17                    NaN
# 2020-06-16                    NaN
# 2020-06-12                    NaN
# 2020-06-11                    NaN
# 2020-06-10                    NaN
# 2020-06-09                    NaN
# 2020-06-08                    NaN
# 2020-06-05                    NaN
# 2020-06-04                    NaN
# 2020-06-03                    NaN
# 2020-06-02                    NaN
# 2020-06-01                    NaN
# 2020-05-29                    NaN
# 2020-05-28                    NaN
# 2020-05-27                    NaN
# 2020-05-26                    NaN
# 2020-05-22                    NaN
# 2020-05-21                    NaN
# 2020-05-20                    NaN
# 2020-05-19                    NaN
# 2020-05-18                    NaN
# 2020-05-15                    NaN
# 2020-05-14             610.138333
# 2020-05-13             606.071667
# 2020-05-12             602.778333
# 2020-05-11             599.205000
# 2020-05-08             594.761667
# 2020-05-07             589.950000

# %%
plt.figure(figsize=(13,9))
ypf["Cierre"].plot(kind="line", label="Verdadero")
media_movil["Cierre"].plot(kind="line", label="Media Movil")
plt.title("Valor de Cierre - YPF", pad=10, fontdict={'fontsize':20});
plt.legend()

# %%
ypf["Cierre"].expanding().mean().plot(kind="line")

# %% [markdown]
# ### Subselección

# %%
ypf["Cierre"]["2005-11-25": "2006-11-25"]
# Out:
# Series([], Name: Cierre, dtype: float64)

# %%
ypf["Cierre"]
# Out:
# Fecha Cotización
# 2020-06-26    608.85
# 2020-06-25    618.45
# 2020-06-24    597.90
# 2020-06-23    611.10
# 2020-06-22    608.65
#                ...
# 2001-12-07     20.90
# 2001-12-06     19.00
# 2001-12-05     18.00
# 2001-12-04     16.50
# 2001-12-03     16.00
# Name: Cierre, Length: 4597, dtype: float64
